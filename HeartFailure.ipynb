# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaXzaviero/BENGKEL-KODING/blob/main/HeartFailure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv ('/content/heart_failure.csv')

# %%
df.head()
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0  40.0   M           ATA      140.0        289.0        0.0     Normal
# 1  49.0   F           NAP      160.0        180.0        0.0     Normal
# 2  37.0   M           ATA      130.0        283.0        0.0         ST
# 3  48.0   F           ASY      138.0        214.0        0.0     Normal
# 4  54.0   M           NAP      150.0        195.0        0.0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0  172.0              N      0.0       Up           0.0
# 1  156.0              N      1.0     Flat           1.0
# 2   98.0              N      0.0       Up           0.0
# 3  108.0              Y      1.5     Flat           1.0
# 4  122.0              N      0.0       Up           0.0

# %%
df.tail()
# Out:
#        Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1234  29.0   F           ATA      120.0          NaN        1.0        LVH
# 1235  70.0   M           NAP      150.0        180.0        1.0         ST
# 1236  60.0   M           ATA      130.0        300.0        1.0     Normal
# 1237  50.0   M           ASY      120.0        300.0        NaN         ST
# 1238  40.0   F           ATA      140.0        250.0        0.0         ST
#
#       MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 1234  100.0              Y      2.0     Flat           0.0
# 1235  180.0              N      3.0     Flat           0.0
# 1236  160.0              N      1.0       Up           1.0
# 1237  140.0              N      1.0     Down           0.0
# 1238  140.0              Y      2.0     Flat           1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1239 entries, 0 to 1238
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             1230 non-null   float64
#  1   Sex             1234 non-null   object
#  2   ChestPainType   1232 non-null   object
#  3   RestingBP       1231 non-null   float64
#  4   Cholesterol     1229 non-null   float64
#  5   FastingBS       1234 non-null   float64
#  6   RestingECG      1234 non-null   object
#  7   MaxHR           1233 non-null   float64
#  8   ExerciseAngina  1235 non-null   object
#  9   Oldpeak         1233 non-null   float64
#  10  ST_Slope        1232 non-null   object
#  11  HeartDisease    1236 non-null   float64
# dtypes: float64(7), object(5)
# memory usage: 116.3+ KB

# %%
df.shape
# Out:
# (1239, 12)

# %%
df.describe()
# Out:
#                Age    RestingBP  Cholesterol    FastingBS        MaxHR  \
# count  1230.000000  1231.000000  1229.000000  1234.000000  1233.000000
# mean     51.724390   135.047116   206.729862     0.299028   137.557989
# std      11.355974    21.379940    98.582107     0.461545    27.518915
# min      28.000000     0.000000     0.000000     0.000000    20.000000
# 25%      43.000000   120.000000   180.000000     0.000000   120.000000
# 50%      53.000000   130.000000   220.000000     0.000000   140.000000
# 75%      60.000000   145.000000   264.000000     1.000000   160.000000
# max     110.000000   351.000000   603.000000     2.000000   398.000000
#
#            Oldpeak  HeartDisease
# count  1233.000000   1236.000000
# mean      1.054177      0.532362
# std       1.174154      0.500773
# min      -5.000000      0.000000
# 25%       0.000000      0.000000
# 50%       1.000000      1.000000
# 75%       2.000000      1.000000
# max       7.000000      2.000000

# %%
df.isnull().sum()
# Out:
# Age                9
# Sex                5
# ChestPainType      7
# RestingBP          8
# Cholesterol       10
# FastingBS          5
# RestingECG         5
# MaxHR              6
# ExerciseAngina     4
# Oldpeak            6
# ST_Slope           7
# HeartDisease       3
# dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), cbar=False)
plt.title('Missing Values Heatmap')
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in df.columns:
  print(f"Unique Values in coloum '{col}':")
  print(df[col].unique())
  print("-" * 30)
# Out:
# Unique Values in coloum 'Age':
# [ 40.  49.  37.  48.  54.  39.  45.  58.  42.  38.  43.  60.  36.  44.
#   53.  52.  51.  56.  41.  32.  65.  35.  59.  50.  47.  31.  46.  57.
#   55.  63.  66.  34.  33.  61.  29.  62.  28.  30.  74.  68.  72.  64.
#   69.  67.  73.  70.  77.  75.  76.  71.  nan 110.]
# ------------------------------
# Unique Values in coloum 'Sex':
# ['M' 'F' 'unk' nan '??' ' ']
# ------------------------------
# Unique Values in coloum 'ChestPainType':
# ['ATA' 'NAP' 'ASY' 'TA' nan 'unk' ' ']
# ------------------------------
# Unique Values in coloum 'RestingBP':
# [140. 160. 130. 138. 150. 120. 110. 136. 115. 100. 124. 113. 125. 145.
#  112. 132. 118. 170. 142. 190. 135. 180. 108. 155. 128. 106.  92. 200.
#  122.  98. 105. 133.  95.  80. 137. 185. 165. 126. 152. 116.   0. 144.
#  154. 134. 104. 139. 131. 141. 178. 146. 158. 123. 102.  96. 143. 172.
#  156. 114. 127. 101. 174.  94. 148. 117. 192. 129. 164.  nan 313. 351.]
# ------------------------------
# ...

# %%
suspects = ['?','??','NA','N/A',
            'na','None','null','Null',
            'Unknown','UNK','-','- -',' ',
            'Nan','XXX','unk',9999, -9999]

for val in suspects:
    print(f"{val}:")
    print((df == val).sum())
# Out:
# ?:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64
# ??:
# Age               0
# Sex               1
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        1
# MaxHR             0
# ExerciseAngina    1
# Oldpeak           0
# ST_Slope          1
# HeartDisease      0
# dtype: int64
# NA:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64
# N/A:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# ...

# %%
num_cols = ['Age' , 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']

plt.figure(figsize=(12, 6))

sns.boxplot(data=df[num_cols], orient='h', palette='Set2')

plt.title('Check outlier pada fitur numerik', fontsize=16, pad=15)
plt.xlabel('Nilai', fontsize=12)
plt.ylabel('Fitur', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='HeartDisease', palette='viridis')
plt.title('Distribution of HeartDisease')
plt.xlabel('HeartDisease')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipykernel_2983/1255029059.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='HeartDisease', palette='viridis')

# %%
df[num_cols].hist(figsize=(12, 6), bins=20)
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'RestingBP'}>],
#        [<Axes: title={'center': 'Cholesterol'}>,
#         <Axes: title={'center': 'MaxHR'}>],
#        [<Axes: title={'center': 'Oldpeak'}>, <Axes: >]], dtype=object)

# %%
cat_cols = ['Sex', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope', 'HeartDisease']

for col in cat_cols:
    print(f"\n{col} unique values:", df[col].nunique())
    print(df[col].value_counts().head(10))

for col in cat_cols:
    if df[col].nunique() < 50:
        plt.figure(figsize=(10, 6))
        sns.countplot(data=df, y=col,
                    order=df[col].value_counts().index,
                    palette='viridis')
        plt.title(f'Distribution of {col}')
        plt.xlabel('Count')
        plt.ylabel(col)
        plt.tight_layout()
        plt.show()
    else:
      print(f"Skipping plot for '{col}' due to high number of unique values ({df[col].nunique()})")
# Out:
# Sex unique values: 5
# Sex
# M      872
# F      359
# unk      1
# ??       1
#          1
# Name: count, dtype: int64
#
# ChestPainType unique values: 6
# ChestPainType
# ASY    568
# ATA    280
# NAP    265
# TA     117
# unk      1
#          1
# Name: count, dtype: int64
#
# FastingBS unique values: 3
# FastingBS
# 0.0    867
# 1.0    365
# 2.0      2
# Name: count, dtype: int64
#
# RestingECG unique values: 5
# RestingECG
# Normal    658
# ST        290
# LVH       284
# ??          1
#             1
# Name: count, dtype: int64
#
# ExerciseAngina unique values: 6
# ExerciseAngina
# N      707
# Y      524
# ??       1
#          1
# XXX      1
# unk      1
# Name: count, dtype: int64
#
# ST_Slope unique values: 6
# ST_Slope
# Flat    566
# Up      492
# Down    171
# XXX       1
# ??        1
#           1
# Name: count, dtype: int64
#
# HeartDisease unique values: 3
# HeartDisease
# 1.0    656
# 0.0    579
# 2.0      1
# Name: count, dtype: int64
# ...

# %%
plt.figure(figsize=(8, 6))
pearson_matrix = df[num_cols].corr(method='pearson')
sns.heatmap(pearson_matrix, annot=True, cmap='coolwarm', fmt ='.2f', vmin=-1, vmax=1)
plt.title('Matriks Korelasi Pearson\n(khusus fitur Numerik kontinu)', fontsize=14, pad=15)
plt.show()

# %%
from scipy.stats import chi2_contingency

def cramers_v(x,y):
    confusion_matrix = pd.crosstab(x, y)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    r, c = confusion_matrix.shape
    if min(r-1, c-1) == 0:
        return 0.0
    return np.sqrt((chi2/n) / min(r-1, c-1))

cramer_matrix = pd.DataFrame(index=cat_cols, columns=cat_cols)
for coll in cat_cols:
    for col2 in cat_cols:
        cramer_matrix.loc[coll, col2] = cramers_v(df[coll], df[col2])

cramer_matrix = cramer_matrix.astype(float)

plt.figure(figsize=(10, 8))
sns.heatmap(cramer_matrix, annot=True, cmap='Blues', fmt='.2f', vmin=0, vmax=1)
plt.title("Asosiasi Cramer's V\n(khusus fitur kategorikal & Target Biner)", fontsize=14, pad=15)
plt.show()
plt.show()

# %%
from scipy.stats import f_oneway

fig, axes = plt.subplots(1, len(num_cols), figsize=(20, 5))
fig.suptitle('Distribusi Fitur Numerik Terhadap HearthDisease (Uji ANOVA)', fontsize=16, y=1.05)

for i, col in enumerate(num_cols):
    sns.boxplot(x='HeartDisease', y=col, data=df, ax=axes[i], palette='Set2')
    group0 = df[df['HeartDisease'] == 0][col].dropna()
    group1 = df[df['HeartDisease'] == 1][col].dropna()

    if len(group0) > 0 and len(group1) > 0:
        f_stat, p_val = f_oneway(group0, group1)
        axes[i].set_title(f"{col} p-value: {p_val:.4f}")
    else :
        axes[i].set_title(col)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2983/1119573316.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='HeartDisease', y=col, data=df, ax=axes[i], palette='Set2')
# /tmp/ipykernel_2983/1119573316.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='HeartDisease', y=col, data=df, ax=axes[i], palette='Set2')
# /tmp/ipykernel_2983/1119573316.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='HeartDisease', y=col, data=df, ax=axes[i], palette='Set2')
# /tmp/ipykernel_2983/1119573316.py:7: FutureWarning:
#
# ...
